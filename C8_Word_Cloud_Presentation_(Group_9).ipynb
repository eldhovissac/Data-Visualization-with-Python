# %% [markdown]
# <a href="https://colab.research.google.com/github/eldhovissac/Data-Visualization-with-Python/blob/main/C8_Word_Cloud_Presentation_(Group_9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("CarSalesByModelStart2.xlsx")

# %%
df.head()
# Out:
#    Year    Month                Date      Model  Dealer ID  Quantity Sold  \
# 0  2018  January 2018-01-01 23:00:00   Beaufort       1222             10
# 1  2018  January 2018-01-01 23:00:00     Salish       1222             13
# 2  2018  January 2018-01-01 23:00:00   Labrador       1222             16
# 3  2018  January 2018-01-01 23:00:00  Champlain       1222              3
# 4  2018  January 2018-01-01 23:00:00     Hudson       1222             22
#
#     Profit
# 0  15000.0
# 1  39650.0
# 2  12800.0
# 3   6900.0
# 4  11000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           1200 non-null   int64
#  1   Month          1200 non-null   object
#  2   Date           1200 non-null   datetime64[ns]
#  3   Model          882 non-null    object
#  4   Dealer ID      1200 non-null   int64
#  5   Quantity Sold  1200 non-null   int64
#  6   Profit         1200 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 65.8+ KB

# %%
df.isna().sum()
# Out:
# Year               0
# Month              0
# Date               0
# Model            318
# Dealer ID          0
# Quantity Sold      0
# Profit             0
# dtype: int64

# %%
#Removing NaN Values
df.dropna(inplace = True)

#Creating the text variable
text1 = " ".join(Name for Name in df.Model)
print(text1)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text1)
# Display the generated Word Cloud
# Out:
# Beaufort Salish Labrador Champlain Hudson Beaufort Salish Labrador Champlain Hudson Beaufort Salish Labrador Champlain Hudson Beaufort Salish Labrador Champlain Hudson Beaufort Salish Labrador Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Hudson Beaufort Salish Champlain Beaufort Salish Champlain Beaufort Salish Champlain Beaufort Salish Champlain Beaufort Champlain Beaufort Champlain Beaufort Champlain 
# ...

# %%
fig=plt.figure(figsize=(14, 18))

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")

plt.show()
